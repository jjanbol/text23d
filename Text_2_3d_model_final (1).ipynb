# %% [markdown]
# # **Load the Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade objaverse
# !pip install torch torchvision torchaudio trimesh numpy objaverse tqdm
# Out:
# Collecting objaverse
#   Downloading objaverse-0.1.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from objaverse) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from objaverse) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from objaverse) (18.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from objaverse) (4.67.1)
# Collecting loguru (from objaverse)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: fsspec>=2022.11.0 in /usr/local/lib/python3.11/dist-packages (from objaverse) (2025.3.2)
# Collecting gputil==1.4.0 (from objaverse)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->objaverse) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->objaverse) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->objaverse) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->objaverse) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->objaverse) (1.17.0)
# Downloading objaverse-0.1.7-py3-none-any.whl (32 kB)
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.2 MB/s eta 0:00:00
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=e427f14b8983d8e789b77efe57d7a435d1f215aa4c6dd9359adc8370d52025e3
#   Stored in directory: /root/.cache/pip/wheels/2b/4d/8f/55fb4f7b9b591891e8d3f72977c4ec6c7763b39c19f0861595
# Successfully built gputil
# Installing collected packages: gputil, loguru, objaverse
# Successfully installed gputil-1.4.0 loguru-0.7.3 objaverse-0.1.7
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting trimesh
#   Downloading trimesh-4.6.8-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: objaverse in /usr/local/lib/python3.11/dist-packages (0.1.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from objaverse) (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from objaverse) (2.2.2)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from objaverse) (18.1.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.11/dist-packages (from objaverse) (0.7.3)
# Requirement already satisfied: gputil==1.4.0 in /usr/local/lib/python3.11/dist-packages (from objaverse) (1.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->objaverse) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->objaverse) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->objaverse) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->objaverse) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->objaverse) (1.17.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 123.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 65.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.9 MB/s eta 0:00:00
# Downloading trimesh-4.6.8-py3-none-any.whl (709 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.3/709.3 kB 48.1 MB/s eta 0:00:00
# Installing collected packages: trimesh, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 trimesh-4.6.8

# %% [markdown]
# # **Load the Components**

# %%
# %matplotlib inline
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from torch.optim.lr_scheduler import CosineAnnealingLR
import objaverse
import trimesh
import gc
from sentence_transformers import SentenceTransformer
from tqdm import tqdm
import logging
import matplotlib.pyplot as plt

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Define device
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
logger.info(f"Using device: {DEVICE}")

# %%
uuid_embeddings = np.load("/content/drive/MyDrive/Project/df_english.npy", allow_pickle=True)

# %%
uuid_embeddings
# Out:
# array([['bfd459469a9449978ff5fc7199d5848b',
#         "3D Mandala #2 - The Power of Love went a bit weird with this one.. in the centre a blue female is punching the red male, breaking his heart in the process, triggering feelings like he's being anally probed by aliens, sending shocks through his eyeball, releasing some tears."],
#        ['a4bb737d810049c98680a53262552a7b',
#         "Glass 眼睛 A Glass which don't have shader and i don't know why"],
#        ['01474f78a328473b8d99ded65effb2cc',
#         'Low Poly Barrel super simple barrel'],
#        ...,
#        ['69925e5dab364b4ba87b036f6042c442',
#         'Consolevert4 SciFi Controls \n\nFree to use in commercial and personal projects!\n\nEnjoy!'],
#        ['63b0f1e3ccdd4b3fabec4443a2b25cd8',
#         'Neo-Normcore Collection, Insulin Placebo Human Insulin Hexamer by model3dbiology is licensed under CC Attribution'],
#        ['168bb415db3247a19e5fcc4d23c26c91',
#         "R.O.Y. Bot Zbrush, Go-Z'd to C4D create OVDB Bevels and baked in 3D Coat. Sci-Fi Mech, Mecha, Robot."]],
#       dtype=object)

# %%
uuid_embeddings.shape
# Out:
# (236277, 2)

# %%
uuid_embeddings[0, 1]
# Out:
# "3D Mandala #2 - The Power of Love went a bit weird with this one.. in the centre a blue female is punching the red male, breaking his heart in the process, triggering feelings like he's being anally probed by aliens, sending shocks through his eyeball, releasing some tears."

# %%
import numpy as np
import objaverse
import os
import trimesh
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from tqdm import tqdm
import logging
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import CosineAnnealingLR
from sentence_transformers import SentenceTransformer

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

def generate_triplane_from_mesh(obj_path, triplane_resolution=128, voxel_resolution=128, device='cuda'):
    try:
        mesh = trimesh.load(obj_path, force='mesh', process=False)
        if isinstance(mesh, trimesh.Scene):
            mesh = mesh.dump(concatenate=True)
        if not isinstance(mesh, trimesh.Trimesh):
            logger.error(f"Invalid mesh at {obj_path}: not a Trimesh")
            return None
        if len(mesh.vertices) == 0 or len(mesh.faces) == 0:
            logger.error(f"Empty mesh at {obj_path}")
            return None

        center = mesh.bounds.mean(axis=0)
        mesh.apply_translation(-center)
        max_extent = np.ptp(mesh.bounds, axis=0).max()
        if max_extent > 1e-6:
            mesh.apply_scale(1.0 / max_extent)

        pitch = 1.0 / voxel_resolution
        voxel_grid = mesh.voxelized(pitch=pitch)
        voxel_matrix = voxel_grid.matrix.astype(np.float32)

        current_shape = voxel_matrix.shape
        target_shape = (voxel_resolution, voxel_resolution, voxel_resolution)
        padded_matrix = np.zeros(target_shape, dtype=np.float32)
        min_shape = tuple(min(s, t) for s, t in zip(current_shape, target_shape))
        padded_matrix[:min_shape[0], :min_shape[1], :min_shape[2]] = \
            voxel_matrix[:min_shape[0], :min_shape[1], :min_shape[2]]
        voxel_matrix = padded_matrix

        if voxel_matrix.sum() == 0:
            logger.error(f"Empty voxel grid for {obj_path}")
            return None

        plane_xy = np.max(voxel_matrix, axis=2)
        plane_yz = np.max(voxel_matrix, axis=0)
        plane_xz = np.max(voxel_matrix, axis=1)

        plane_xy_t = torch.from_numpy(plane_xy).unsqueeze(0).float().to(device)
        plane_yz_t = torch.from_numpy(plane_yz).unsqueeze(0).float().to(device)
        plane_xz_t = torch.from_numpy(plane_xz).unsqueeze(0).float().to(device)

        target_size = (triplane_resolution, triplane_resolution)
        plane_xy_t = F.interpolate(plane_xy_t.unsqueeze(0), size=target_size, mode='bilinear', align_corners=False).squeeze(0)
        plane_yz_t = F.interpolate(plane_yz_t.unsqueeze(0), size=target_size, mode='bilinear', align_corners=False).squeeze(0)
        plane_xz_t = F.interpolate(plane_xz_t.unsqueeze(0), size=target_size, mode='bilinear', align_corners=False).squeeze(0)

        plane_xy_t = torch.clamp(plane_xy_t, 0.0, 1.0)
        plane_yz_t = torch.clamp(plane_yz_t, 0.0, 1.0)
        plane_xz_t = torch.clamp(plane_xz_t, 0.0, 1.0)

        return plane_xy_t.cpu(), plane_yz_t.cpu(), plane_xz_t.cpu()
    except Exception as e:
        logger.error(f"Failed to process mesh at {obj_path}: {e}")
        return None

def generate_and_save_triplanes(caption_data_path, output_dir=None, start_index=0, end_index=None, triplane_resolution=128, voxel_resolution=128, device='cuda'):
    if output_dir is None:
        output_dir = os.path.dirname(caption_data_path)
    os.makedirs(output_dir, exist_ok=True)

    try:
        caption_data = np.load(caption_data_path, allow_pickle=True)
        logger.info(f"Loaded caption data with shape: {caption_data.shape}")
    except Exception as e:
        logger.error(f"Failed to load caption data: {e}")
        return

    max_index = caption_data.shape[0]
    if start_index < 0 or start_index >= max_index:
        logger.error(f"start_index {start_index} is out of bounds [0, {max_index})")
        return
    if end_index is None:
        end_index = max_index
    if end_index <= start_index or end_index > max_index:
        logger.error(f"end_index {end_index} is invalid; must be > {start_index} and <= {max_index}")
        return

    uuids = caption_data[start_index:end_index, 0]
    captions = caption_data[start_index:end_index, 1]

    for uuid, caption in tqdm(zip(uuids, captions), total=len(uuids), desc=f"Generating triplanes [{start_index}:{end_index}]"):
        try:
            objects = objaverse.load_objects(uids=[uuid])
            if uuid not in objects:
                logger.warning(f"Model {uuid} not found in Objaverse")
                continue
            obj_path = objects[uuid]
            if not isinstance(obj_path, str) or not os.path.exists(obj_path):
                logger.error(f"Invalid or missing file for {uuid}: {obj_path}")
                continue

            triplane = generate_triplane_from_mesh(obj_path, triplane_resolution, voxel_resolution, device)
            if triplane is None:
                logger.warning(f"Failed to generate triplane for {uuid}")
                continue

            plane_xy, plane_yz, plane_xz = triplane
            data = {
                'plane_xy': plane_xy.numpy(),
                'plane_yz': plane_yz.numpy(),
                'plane_xz': plane_xz.numpy(),
                'caption': caption
            }

            output_path = os.path.join(output_dir, f"{uuid}.npy")
            np.save(output_path, data)
            logger.info(f"Saved triplane and caption for {uuid} to {output_path}")

            del triplane, plane_xy, plane_yz, plane_xz, data
            torch.cuda.empty_cache() if device == 'cuda' else None

        except Exception as e:
            logger.error(f"Failed to process model {uuid}: {e}")
            continue

class TriplaneTextFromFilesDataset(Dataset):
    def __init__(self, triplane_dir, num_models=None, device='cuda'):
        self.triplane_dir = triplane_dir
        self.device = device

        self.npy_files = [f for f in os.listdir(triplane_dir) if f.endswith('.npy')]
        if not self.npy_files:
            logger.error(f"No .npy files found in {triplane_dir}")
            raise ValueError(f"No .npy files found in {triplane_dir}")

        if num_models is not None:
            self.npy_files = self.npy_files[:min(num_models, len(self.npy_files))]

        self.valid_files = []
        self.uuids = []

        for npy_file in tqdm(self.npy_files, desc="Validating .npy files"):
            try:
                file_path = os.path.join(self.triplane_dir, npy_file)
                data = np.load(file_path, allow_pickle=True).item()
                if not all(key in data for key in ['plane_xy', 'plane_yz', 'plane_xz', 'caption']):
                    logger.warning(f"Invalid .npy file {npy_file}: missing required keys")
                    continue
                if data['plane_xy'].shape != (1, 128, 128) or \
                   data['plane_yz'].shape != (1, 128, 128) or \
                   data['plane_xz'].shape != (1, 128, 128):
                    logger.warning(f"Invalid .npy file {npy_file}: incorrect triplane shapes")
                    continue
                self.valid_files.append(npy_file)
                self.uuids.append(npy_file.replace('.npy', ''))
            except Exception as e:
                logger.warning(f"Failed to load {npy_file}: {e}")
                continue

        if not self.valid_files:
            logger.error(f"No valid .npy files found in {triplane_dir}")
            raise ValueError(f"No valid .npy files found in {triplane_dir}")

        logger.info(f"Initialized dataset with {len(self.valid_files)} valid samples")

    def __len__(self):
        return len(self.valid_files)

    def __getitem__(self, idx):
        npy_file = self.valid_files[idx]
        file_path = os.path.join(self.triplane_dir, npy_file)

        try:
            data = np.load(file_path, allow_pickle=True).item()
            plane_xy = torch.from_numpy(data['plane_xy']).float().to(self.device)
            plane_yz = torch.from_numpy(data['plane_yz']).float().to(self.device)
            plane_xz = torch.from_numpy(data['plane_xz']).float().to(self.device)
            caption = str(data['caption'])
            return (plane_xy, plane_yz, plane_xz), caption
        except Exception as e:
            logger.error(f"Failed to load {npy_file}: {e}")
            raise e

class PositionalEncoding2D(nn.Module):
    def __init__(self, d_model, height, width):
        super().__init__()
        if d_model % 4 != 0:
            raise ValueError(f"Cannot use sin/cos positional encoding with odd dimension (got dim={d_model})")
        pe = torch.zeros(d_model, height, width)
        d_model_h = d_model // 2
        d_model_w = d_model // 2
        div_term = torch.exp(torch.arange(0., d_model_h, 2) * -(torch.log(torch.tensor(10000.0)) / d_model_h))
        pos_w = torch.arange(0., width).unsqueeze(1)
        pos_h = torch.arange(0., height).unsqueeze(1)
        pe[0:d_model_h:2, :, :] = torch.sin(pos_h * div_term).transpose(0, 1).unsqueeze(2).repeat(1, 1, width)
        pe[1:d_model_h:2, :, :] = torch.cos(pos_h * div_term).transpose(0, 1).unsqueeze(2).repeat(1, 1, width)
        pe[d_model_h::2, :, :] = torch.sin(pos_w * div_term).transpose(0, 1).unsqueeze(1).repeat(1, height, 1)
        pe[d_model_h+1::2, :, :] = torch.cos(pos_w * div_term).transpose(0, 1).unsqueeze(1).repeat(1, height, 1)
        self.register_buffer('pe', pe.unsqueeze(0))

    def forward(self, x):
        x = x + self.pe[:, :, :x.size(2), :x.size(3)]
        return x

class TriplaneDecoder(nn.Module):
    def __init__(self, encoder_dim=384, decoder_dim=512, decoder_layers=4, decoder_heads=8,
                 output_channels=3, output_resolution=128, input_patch_grid_res=16):
        super().__init__()
        self.encoder_dim = encoder_dim
        self.decoder_dim = decoder_dim
        self.output_resolution = output_resolution
        self.input_patch_grid_res = input_patch_grid_res
        self.num_patches = input_patch_grid_res * input_patch_grid_res

        self.input_proj = nn.Linear(encoder_dim, decoder_dim * self.num_patches)
        self.pos_encoder = PositionalEncoding2D(decoder_dim, input_patch_grid_res, input_patch_grid_res)

        decoder_layer = nn.TransformerDecoderLayer(
            d_model=decoder_dim, nhead=decoder_heads, dim_feedforward=decoder_dim * 4,
            dropout=0.1, activation=F.gelu, batch_first=True, norm_first=True)
        self.transformer_decoder = nn.TransformerDecoder(decoder_layer, num_layers=decoder_layers)

        num_upsample_stages = int(torch.log2(torch.tensor(output_resolution // input_patch_grid_res)))
        if input_patch_grid_res * (2**num_upsample_stages) != output_resolution:
            raise ValueError("Output resolution must be a power-of-2 multiple of input_patch_grid_res")

        upsample_layers = []
        current_dim = decoder_dim
        for i in range(num_upsample_stages):
            out_dim = max(decoder_dim // (2**(i+1)), output_channels * 2)
            upsample_layers.append(nn.Sequential(
                nn.ConvTranspose2d(current_dim, out_dim, kernel_size=4, stride=2, padding=1),
                nn.BatchNorm2d(out_dim), nn.GELU(),
                nn.Conv2d(out_dim, out_dim, kernel_size=3, stride=1, padding=1),
                nn.BatchNorm2d(out_dim), nn.GELU()
            ))
            current_dim = out_dim
        self.upsample_neck = nn.Sequential(*upsample_layers)

        self.output_proj = nn.Conv2d(current_dim, output_channels, kernel_size=1, stride=1, padding=0)
        self.output_activation = nn.Sigmoid()

    def forward(self, text_embedding):
        batch_size = text_embedding.shape[0]
        seq = self.input_proj(text_embedding).view(batch_size, self.num_patches, self.decoder_dim)
        spatial_input = seq.permute(0, 2, 1).reshape(
            batch_size, self.decoder_dim, self.input_patch_grid_res, self.input_patch_grid_res)
        spatial_input_with_pos = self.pos_encoder(spatial_input)
        seq_with_pos = spatial_input_with_pos.flatten(2).permute(0, 2, 1)
        refined_seq = self.transformer_decoder(tgt=seq_with_pos, memory=seq_with_pos)
        spatial_features = refined_seq.permute(0, 2, 1).reshape(
            batch_size, self.decoder_dim, self.input_patch_grid_res, self.input_patch_grid_res)
        upsampled_features = self.upsample_neck(spatial_features)
        output_logits = self.output_proj(upsampled_features)
        output_triplane = self.output_activation(output_logits)

        plane_xy = output_triplane[:, 0:1, :, :]
        plane_yz = output_triplane[:, 1:2, :, :]
        plane_xz = output_triplane[:, 2:3, :, :]

        return plane_xy, plane_yz, plane_xz

class TextToTriplaneModel(nn.Module):
    def __init__(self, text_encoder_name='all-MiniLM-L6-v2', decoder_dim=512, decoder_layers=4,
                 decoder_heads=8, output_resolution=128):
        super().__init__()
        self.text_encoder = SentenceTransformer(text_encoder_name)
        self.text_encoder.eval()
        for param in self.text_encoder.parameters():
            param.requires_grad = False
        self.decoder = TriplaneDecoder(
            encoder_dim=384,
            decoder_dim=decoder_dim,
            decoder_layers=decoder_layers,
            decoder_heads=decoder_heads,
            output_channels=3,
            output_resolution=output_resolution,
            input_patch_grid_res=16
        )

    def forward(self, captions, device):
        with torch.no_grad():
            text_embeddings = self.text_encoder.encode(captions, convert_to_tensor=True, device=device)
        plane_xy, plane_yz, plane_xz = self.decoder(text_embeddings)
        return plane_xy, plane_yz, plane_xz

def plot_sample(triplane, caption, uuid, title="Triplane"):
    try:
        if any(ord(char) > 127 for char in caption):
            try:
                plt.rcParams['font.family'] = 'Noto Sans CJK JP'
            except:
                logger.warning("Noto Sans CJK JP font not found, using default.")
                plt.rcParams['font.family'] = 'DejaVu Sans'
        else:
            plt.rcParams['font.family'] = 'DejaVu Sans'

        logger.info(f"Generating plot: {uuid}_{title.replace(' ', '_').lower()}.png")

        plane_xy, plane_yz, plane_xz = triplane
        xy_plane = plane_xy.cpu().numpy()[0]
        yz_plane = plane_yz.cpu().numpy()[0]
        xz_plane = plane_xz.cpu().numpy()[0]
        xy_plane = np.clip(xy_plane, 0, 1)
        yz_plane = np.clip(yz_plane, 0, 1)
        xz_plane = np.clip(xz_plane, 0, 1)
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))
        axes[0].imshow(xy_plane, cmap='gray')
        axes[0].set_title(f"XY Plane\nUUID: {uuid}")
        axes[0].axis('off')
        axes[1].imshow(yz_plane, cmap='gray')
        axes[1].set_title("YZ Plane")
        axes[1].axis('off')
        axes[2].imshow(xz_plane, cmap='gray')
        axes[2].set_title("XZ Plane")
        axes[2].axis('off')
        fig.suptitle(f"{title}\nCaption: {caption}", fontsize=12, y=0.05)
        plt.tight_layout()
        plt.savefig(f"{uuid}_{title.replace(' ', '_').lower()}.png")
        plt.show()
        plt.close()

        plt.rcParams['font.family'] = 'DejaVu Sans'
    except Exception as e:
        logger.error(f"Error plotting sample: {e}")

def plot_triplane_grid(pred_triplane, gt_triplane, caption, uuid, title="Triplane Comparison"):
    try:
        if any(ord(char) > 127 for char in caption):
            try:
                plt.rcParams['font.family'] = 'Noto Sans CJK JP'
            except:
                logger.warning("Noto Sans CJK JP font not found, using default.")
                plt.rcParams['font.family'] = 'DejaVu Sans'
        else:
            plt.rcParams['font.family'] = 'DejaVu Sans'

        logger.info(f"Generating grid plot: {uuid}_{title.replace(' ', '_').lower()}.png with caption: {caption}")

        pred_xy, pred_yz, pred_xz = pred_triplane
        gt_xy, gt_yz, gt_xz = gt_triplane

        pred_xy = np.clip(pred_xy.cpu().numpy()[0, 0], 0, 1)
        pred_yz = np.clip(pred_yz.cpu().numpy()[0, 0], 0, 1)
        pred_xz = np.clip(pred_xz.cpu().numpy()[0, 0], 0, 1)
        gt_xy = np.clip(gt_xy.cpu().numpy()[0], 0, 1)
        gt_yz = np.clip(gt_yz.cpu().numpy()[0], 0, 1)
        gt_xz = np.clip(gt_xz.cpu().numpy()[0], 0, 1)

        fig, axes = plt.subplots(2, 3, figsize=(15, 10))

        axes[0, 0].imshow(pred_xy, cmap='gray')
        axes[0, 0].set_title("Predicted XY Plane")
        axes[0, 0].axis('off')
        axes[0, 1].imshow(pred_yz, cmap='gray')
        axes[0, 1].set_title("Predicted YZ Plane")
        axes[0, 1].axis('off')
        axes[0, 2].imshow(pred_xz, cmap='gray')
        axes[0, 2].set_title("Predicted XZ Plane")
        axes[0, 2].axis('off')

        axes[1, 0].imshow(gt_xy, cmap='gray')
        axes[1, 0].set_title("Ground Truth XY Plane")
        axes[1, 0].axis('off')
        axes[1, 1].imshow(gt_yz, cmap='gray')
        axes[1, 1].set_title("Ground Truth YZ Plane")
        axes[1, 1].axis('off')
        axes[1, 2].imshow(gt_xz, cmap='gray')
        axes[1, 2].set_title("Ground Truth XZ Plane")
        axes[1, 2].axis('off')

        fig.suptitle(f"{title}\nCaption: {caption}\nUUID: {uuid}", fontsize=12, y=0.02)
        plt.tight_layout()
        plt.savefig(f"{uuid}_{title.replace(' ', '_').lower()}.png")
        plt.show()
        plt.close()

        plt.rcParams['font.family'] = 'DejaVu Sans'
    except Exception as e:
        logger.error(f"Error plotting triplane grid: {e}")
        raise e

def train_model(model, train_loader, val_loader, npy_file_path, num_epochs=10, lr=1e-3, device='cuda', checkpoint_dir='.'):
    model = model.to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs)
    criterion = nn.L1Loss()

    best_val_loss = float('inf')
    best_model_path = os.path.join(checkpoint_dir, "best_text_to_triplane_model.pth")

    os.makedirs(checkpoint_dir, exist_ok=True)

    logger.info(f"Loading .npy file: {npy_file_path}")
    try:
        data = np.load(not all(key in data for key in ['plane_xy', 'plane_yz', 'plane_xz', 'caption']))
        if data['plane_xy'].shape != (1, 128, 128) or \
           data['plane_yz'].shape != (1, 128, 128) or \
           data['plane_xz'].shape != (1, 128, 128):
            raise ValueError(f"Invalid .npy file {npy_file_path}: incorrect triplane shapes")
        npy_caption = str(data['caption'])
        npy_gt_xy = torch.from_numpy(data['plane_xy']).float()
        npy_gt_yz = torch.from_numpy(data['plane_yz']).float()
        npy_gt_xz = torch.from_numpy(data['plane_xz']).float()
        logger.info(f"Successfully loaded .npy file with caption: {npy_caption}")
    except Exception as e:
        logger.error(f"Failed to load {npy_file_path}: {e}")
        raise e

    prev_pred_triplane = None

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        for triplane, caption in tqdm(train_loader, desc=f"Epoch {epoch+1} Training"):
            triplane_xy, triplane_yz, triplane_xz = triplane
            triplane_xy = triplane_xy.to(device)
            triplane_yz = triplane_yz.to(device)
            triplane_xz = triplane_xz.to(device)
            optimizer.zero_grad()
            output_xy, output_yz, output_xz = model(caption, device=device)
            loss_xy = criterion(output_xy, triplane_xy)
            loss_yz = criterion(output_yz, triplane_yz)
            loss_xz = criterion(output_xz, triplane_xz)
            loss = (loss_xy + loss_yz + loss_xz) / 3
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item()
            torch.cuda.empty_cache() if device == 'cuda' else None
        train_loss /= len(train_loader)

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for triplane, caption in tqdm(val_loader, desc=f"Epoch {epoch+1} Validation"):
                triplane_xy, triplane_yz, triplane_xz = triplane
                triplane_xy = triplane_xy.to(device)
                triplane_yz = triplane_yz.to(device)
                triplane_xz = triplane_xz.to(device)
                output_xy, output_yz, output_xz = model(caption, device=device)
                loss_xy = criterion(output_xy, triplane_xy)
                loss_yz = criterion(output_yz, triplane_yz)
                loss_xz = criterion(output_xz, triplane_xz)
                loss = (loss_xy + loss_yz + loss_xz) / 3
                val_loss += loss.item()
        val_loss /= len(val_loader)

        scheduler.step()

        logger.info(f"Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), best_model_path)
            logger.info(f"Saved best model with Val Loss: {best_val_loss:.4f}")

        if (epoch + 1) % 10 == 0:
            checkpoint_path = os.path.join(checkpoint_dir, f"checkpoint_epoch_{epoch+1}.pth")
            torch.save(model.state_dict(), checkpoint_path)
            logger.info(f"Saved checkpoint at epoch {epoch+1} to {checkpoint_path}")

            logger.info(f"Generating triplanes for .npy file caption at epoch {epoch+1}")
            model.eval()
            with torch.no_grad():
                output_xy, output_yz, output_xz = model([npy_caption], device=device)
                pred_triplane = (output_xy, output_yz, output_xz)
                gt_triplane = (npy_gt_xy, npy_gt_yz, npy_gt_xz)

                if prev_pred_triplane is not None:
                    diff_xy = torch.mean(torch.abs(output_xy - prev_pred_triplane[0])).item()
                    diff_yz = torch.mean(torch.abs(output_yz - prev_pred_triplane[1])).item()
                    diff_xz = torch.mean(torch.abs(output_xz - prev_pred_triplane[2])).item()
                    logger.info(f"Prediction L1 diff between epoch {epoch+1} and {epoch-9}: "
                                f"XY={diff_xy:.6f}, YZ={diff_yz:.6f}, XZ={diff_xz:.6f}")

                prev_pred_triplane = (output_xy.clone(), output_yz.clone(), output_xz.clone())

                plot_triplane_grid(
                    pred_triplane=pred_triplane,
                    gt_triplane=gt_triplane,
                    caption=npy_caption,
                    uuid=f"inference_{os.path.basename(npy_file_path).replace('.npy', '')}_epoch_{epoch+1}",
                    title=f"Triplane Comparison Epoch {epoch+1}"
                )

    return model, best_model_path

def load_model_checkpoint(checkpoint_path, device='cuda', train_mode=False):
    logger = logging.getLogger(__name__)
    try:
        model = TextToTriplaneModel(
            text_encoder_name='all-MiniLM-L6-v2',
            decoder_dim=512,
            decoder_layers=4,
            decoder_heads=8,
            output_resolution=128
        )
        checkpoint = torch.load(checkpoint_path, map_location=device)
        model.load_state_dict(checkpoint)
        logger.info(f"Successfully loaded checkpoint from {checkpoint_path}")
        model = model.to(device)
        if train_mode:
            model.train()
            logger.info("Model set to training mode")
        else:
            model.eval()
            logger.info("Model set to evaluation mode")
        return model
    except FileNotFoundError:
        logger.error(f"Checkpoint file not found: {checkpoint_path}")
        raise
    except Exception as e:
        logger.error(f"Failed to load checkpoint from {checkpoint_path}: {e}")
        raise

def infer_triplane(model, caption, device='cuda'):
    model.eval()
    uuid = f"inference_{hash(caption) % 1000000}"
    with torch.no_grad():
        output_xy, output_yz, output_xz = model([caption], device=device)
        triplane = (output_xy[0], output_yz[0], output_xz[0])
        plot_sample(triplane, caption, uuid, title="Inferred Triplane")
        logger.info(f"Plotted inferred triplane for caption: {caption}")
    return triplane

# %% [markdown]
# # **Configurations**

# %%
# Configuration
CAPTION_DATA_PATH = "/content/drive/MyDrive/Project/df_english.npy"
TRIPLANE_DIR = "/content/drive/MyDrive/Project/triplanes"
CHECKPOINT_DIR = "/content/drive/MyDrive/Project/checkpoints"  # New directory for checkpoints
NPY_FILE_PATH = "/content/drive/MyDrive/Project/triplanes/fecabaeaf1794756b45333b97d6e2374.npy"
START_INDEX = 648
END_INDEX = 700
NUM_MODELS = 5000
TRAIN_SPLIT = 0.75
VAL_SPLIT = 0.20
TEST_SPLIT = 0.05
BATCH_SIZE = 1
NUM_EPOCHS = 100
LEARNING_RATE = 1e-3
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# # **Create the dataset**

# %%
# # Generate triplanes
# generate_and_save_triplanes(
#     caption_data_path=CAPTION_DATA_PATH,
#     output_dir=TRIPLANE_DIR,
#     start_index=START_INDEX,
#     end_index=END_INDEX,
#     triplane_resolution=128,
#     voxel_resolution=128,
#     device=DEVICE
# )

# %%
# def count_files(directory):
#     return len([f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))])

# num_files = count_files(TRIPLANE_DIR)
# print(f"Number of files in {TRIPLANE_DIR}: {num_files}")

# %% [markdown]
# # **Load the Dataset**

# %%
# Create dataset
dataset = TriplaneTextFromFilesDataset(
    triplane_dir=TRIPLANE_DIR,
    num_models=NUM_MODELS,
    device=DEVICE
)

# Split dataset
train_size = int(TRAIN_SPLIT * len(dataset))
val_size = int(VAL_SPLIT * len(dataset))
test_size = len(dataset) - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# Validating .npy files: 100%|██████████| 5000/5000 [01:32<00:00, 53.90it/s]

# %% [markdown]
# # **Load the model and train**

# %%
model = TextToTriplaneModel(
    text_encoder_name='all-MiniLM-L6-v2',
    decoder_dim=512,
    decoder_layers=4,
    decoder_heads=8,
    output_resolution=128
)

best_model_path = "/content/drive/MyDrive/Project/checkpoints/best_text_to_triplane_model.pth"
model = load_model_checkpoint(best_model_path, device=DEVICE, train_mode=False)

# %%
trained_model, best_model_path = train_model(
    model, train_loader, val_loader,
    npy_file_path=NPY_FILE_PATH,
    num_epochs=NUM_EPOCHS, lr=LEARNING_RATE, device=DEVICE,
    checkpoint_dir=CHECKPOINT_DIR
)

# %% [markdown]
# # **Chamfer Distance calculation**

# %%
class TextToTriplaneModel(nn.Module):
    """
    A model that converts text captions to triplanes (XY, YZ, XZ planes).
    """
    def __init__(self, text_encoder_name='all-MiniLM-L6-v2', decoder_dim=512,
                 decoder_layers=4, decoder_heads=8, output_resolution=128):
        super().__init__()
        # Initialize text encoder
        self.text_encoder = SentenceTransformer(text_encoder_name).to(DEVICE)
        # Simple decoder
        self.decoder = nn.Sequential(
            nn.Linear(384, decoder_dim),  # Assuming text encoder outputs 384-dim embeddings
            nn.ReLU(),
            nn.Linear(decoder_dim, 3 * output_resolution * output_resolution)  # Output 3 planes
        ).to(DEVICE)
        self.output_resolution = output_resolution

        # Move model to device
        self.to(DEVICE)

    def forward(self, captions, device=DEVICE):
        """
        Forward pass: Convert captions to triplanes.
        """
        try:
            # Encode captions to embeddings
            embeddings = self.text_encoder.encode(captions, convert_to_tensor=True)
            embeddings = embeddings.to(device)
            logger.debug(f"Text embeddings device: {embeddings.device}")

            # Decode to triplanes
            output = self.decoder(embeddings)
            # Reshape to (batch_size, 1, output_resolution, output_resolution) for each plane
            batch_size = embeddings.size(0)
            planes = output.view(batch_size, 3, 1, self.output_resolution, self.output_resolution)
            pred_xy, pred_yz, pred_xz = planes[:, 0], planes[:, 1], planes[:, 2]

            return pred_xy, pred_yz, pred_xz
        except Exception as e:
            logger.error(f"Error in TextToTriplaneModel forward: {e}")
            raise

def triplane_to_point_cloud(triplane, threshold=0.5, resolution=128, device=DEVICE):
    """
    Convert a triplane to a 3D point cloud.
    """
    plane_xy, plane_yz, plane_xz = triplane
    batch_size = plane_xy.shape[0]
    point_clouds = []

    for i in range(batch_size):
        xy = plane_xy[i].squeeze(0)
        yz = plane_yz[i].squeeze(0)
        xz = plane_xz[i].squeeze(0)

        # Log triplane statistics
        logger.debug(f"Triplane {i} - XY: min={xy.min().item():.4f}, max={xy.max().item():.4f}, mean={xy.mean().item():.4f}")
        logger.debug(f"Triplane {i} - YZ: min={yz.min().item():.4f}, max={yz.max().item():.4f}, mean={yz.mean().item():.4f}")
        logger.debug(f"Triplane {i} - XZ: min={xz.min().item():.4f}, max={xz.max().item():.4f}, mean={xz.mean().item():.4f}")

        # Dynamic threshold
        max_val = max(xy.max().item(), yz.max().item(), xz.max().item())
        threshold_i = threshold
        if max_val < threshold:
            threshold_i = max_val * 0.5 if max_val > 0 else 0.1
            logger.info(f"Triplane {i} max value {max_val:.4f} < threshold {threshold}. Using dynamic threshold: {threshold_i:.4f}")

        xy = (xy > threshold_i).float()
        yz = (yz > threshold_i).float()
        xz = (xz > threshold_i).float()

        points = []

        if xy.sum() > 0:
            y, x = torch.where(xy > 0)
            z = torch.zeros_like(x, dtype=torch.float32, device=device)
            x = (x.float() / (resolution - 1)) * 2 - 1
            y = (y.float() / (resolution - 1)) * 2 - 1
            xy_points = torch.stack([x, y, z], dim=-1)
            points.append(xy_points)

        if yz.sum() > 0:
            z, y = torch.where(yz > 0)
            x = torch.zeros_like(y, dtype=torch.float32, device=device)
            y = (y.float() / (resolution - 1)) * 2 - 1
            z = (z.float() / (resolution - 1)) * 2 - 1
            yz_points = torch.stack([x, y, z], dim=-1)
            points.append(yz_points)

        if xz.sum() > 0:
            z, x = torch.where(xz > 0)
            y = torch.zeros_like(x, dtype=torch.float32, device=device)
            x = (x.float() / (resolution - 1)) * 2 - 1
            z = (z.float() / (resolution - 1)) * 2 - 1
            xz_points = torch.stack([x, y, z], dim=-1)
            points.append(xz_points)

        if not points:
            logger.warning(f"No points found in triplane {i} after thresholding with threshold {threshold_i}")
            point_clouds.append(torch.empty((0, 3), device=device))
        else:
            point_clouds.append(torch.cat(points, dim=0))

    return point_clouds

def chamfer_distance(pc1, pc2, device=DEVICE):
    """
    Compute the Chamfer Distance between two point clouds.
    """
    if pc1.shape[0] == 0 or pc2.shape[0] == 0:
        logger.warning("One or both point clouds are empty")
        return float('inf')

    pc1 = pc1.unsqueeze(1)
    pc2 = pc2.unsqueeze(0)
    dist = torch.sum((pc1 - pc2) ** 2, dim=-1)

    dist1 = dist.min(dim=1)[0]
    dist2 = dist.min(dim=0)[0]

    loss1 = dist1.mean()
    loss2 = dist2.mean()

    return (loss1 + loss2).item()

def plot_chamfer_distances(distances_data, output_path="chamfer_distances.png"):
    """
    Plot Chamfer Distances for each data sample, suitable for Colab.
    """
    if not distances_data:
        logger.error("No valid Chamfer Distances to plot")
        return

    indices = [data[0] for data in distances_data]
    distances = [data[1] for data in distances_data]

    plt.figure(figsize=(12, 6))
    plt.scatter(indices, distances, color='blue', alpha=0.5, label='Chamfer Distance')
    plt.xlabel('Sample Index')
    plt.ylabel('Chamfer Distance')
    plt.title('Chamfer Distance per Validation Sample')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.savefig(output_path)
    plt.show()  # Display plot in Colab
    logger.info(f"Saved Chamfer Distance plot to {output_path}")

def evaluate_chamfer_distance(model, val_loader, device=DEVICE, threshold=0.5,
                             resolution=128, max_samples=None, plot_path="chamfer_distances.png"):
    """
    Evaluate Chamfer Distance on the validation dataset.
    """
    model.eval()
    chamfer_distances = []
    distances_data = []
    sample_count = 0

    # Ensure model is on the correct device
    model.to(device)
    logger.info("Model moved to device: %s", device)

    with torch.no_grad():
        for triplane, captions in tqdm(val_loader, desc="Evaluating Validation Pairs"):
            try:
                # Move ground truth triplanes to device
                gt_triplane = (
                    triplane[0].to(device),
                    triplane[1].to(device),
                    triplane[2].to(device)
                )

                # Generate predicted triplanes
                pred_xy, pred_yz, pred_xz = model(captions, device=device)
                pred_triplane = (pred_xy, pred_yz, pred_xz)

                # Log predicted triplane statistics
                logger.info(f"Pred XY: min={pred_xy.min().item():.4f}, max={pred_xy.max().item():.4f}, mean={pred_xy.mean().item():.4f}")
                logger.info(f"Pred YZ: min={pred_yz.min().item():.4f}, max={pred_yz.max().item():.4f}, mean={pred_yz.mean().item():.4f}")
                logger.info(f"Pred XZ: min={pred_xz.min().item():.4f}, max={pred_xz.max().item():.4f}, mean={pred_xz.mean().item():.4f}")

                # Convert triplanes to point clouds
                gt_points_list = triplane_to_point_cloud(
                    gt_triplane, threshold=threshold, resolution=resolution, device=device
                )
                pred_points_list = triplane_to_point_cloud(
                    pred_triplane, threshold=threshold, resolution=resolution, device=device
                )

                # Compute Chamfer Distances
                for i, (gt_points, pred_points, caption) in enumerate(zip(gt_points_list, pred_points_list, captions)):
                    logger.info(f"Sample {sample_count} - GT Points: {gt_points.shape[0]}, Pred Points: {pred_points.shape[0]}")
                    cd = chamfer_distance(gt_points, pred_points, device=device)
                    if np.isfinite(cd):
                        chamfer_distances.append(cd)
                        distances_data.append((sample_count, cd, caption))
                        logger.info(f"Caption: {caption[:50]}..., Chamfer Distance: {cd:.6f}")
                    else:
                        logger.warning(f"Invalid Chamfer Distance for caption: {caption[:50]}...")

                    sample_count += 1
                    if max_samples and sample_count >= max_samples:
                        break

                # Clean up
                del gt_points_list, pred_points_list, pred_xy, pred_yz, pred_xz
                if device.type == 'cuda':
                    torch.cuda.empty_cache()

                if max_samples and sample_count >= max_samples:
                    break

            except Exception as e:
                logger.error(f"Error processing batch with captions {[c[:50] for c in captions]}...: {e}")
                continue

    # Summarize results
    if chamfer_distances:
        max_cd = max(chamfer_distances)
        min_cd = min(chamfer_distances)
        avg_cd = np.mean(chamfer_distances)
        logger.info(f"Chamfer Distance Statistics: Max={max_cd:.6f}, Min={min_cd:.6f}, Avg={avg_cd:.6f}")
    else:
        logger.error("No valid Chamfer Distances computed")
        max_cd, min_cd, avg_cd = None, None, None

    return {
        'max_chamfer': max_cd,
        'min_chamfer': min_cd,
        'avg_chamfer': avg_cd,
        'distances': chamfer_distances,
        'distances_data': distances_data
    }

# Verify model parameters
logger.info("Checking model parameter devices:")
for name, param in model.named_parameters():
    logger.info(f"Parameter {name} is on device: {param.device}")

# Evaluate
results = evaluate_chamfer_distance(
    model=model,
    val_loader=val_loader,
    device=DEVICE,
    threshold=0.5,
    resolution=128,
    max_samples=1000,
    plot_path="chamfer_distances.png"
)

# Print and plot results
print(f"Chamfer Distance Results:")
if results['max_chamfer'] is not None:
    print(f"Maximum: {results['max_chamfer']:.6f}")
    print(f"Minimum: {results['min_chamfer']:.6f}")
    print(f"Average: {results['avg_chamfer']:.6f}")
    # Plot the results
    plot_chamfer_distances(results['distances_data'], output_path="chamfer_distances.png")
else:
    print("No valid Chamfer Distances computed. Check device mismatch errors.")
# Out:
# Evaluating Validation Pairs:   0%|          | 0/1000 [00:00<?, ?it/s]ERROR:__main__:Error processing batch with captions ['Old French Mail Box Scan of an old mail box.\nFeel ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   0%|          | 1/1000 [00:00<02:00,  8.30it/s]ERROR:__main__:Error processing batch with captions ['Low Poly Furniture Set Low poly, hand drawn, shade']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   0%|          | 2/1000 [00:00<02:03,  8.09it/s]ERROR:__main__:Error processing batch with captions ['Rainbow pony 1 the first rainbow pony.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   0%|          | 3/1000 [00:00<01:59,  8.35it/s]ERROR:__main__:Error processing batch with captions ['Chisel Model by eucocker']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['default http://staircon.com/ <br>Export by <b>Sale']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   0%|          | 5/1000 [00:00<01:58,  8.40it/s]ERROR:__main__:Error processing batch with captions ['Family Apartments Home Design 3D']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   1%|          | 6/1000 [00:00<01:56,  8.57it/s]ERROR:__main__:Error processing batch with captions ['Areca nut scissors – kacip The presented tool come']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['1107_20 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   1%|          | 8/1000 [00:00<01:37, 10.15it/s]ERROR:__main__:Error processing batch with captions ['u http://staircon.com/ <br>Export by <b>ProStair</']...: CUDA out of memory. Tried to allocate 4.76 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.68 GiB is allocated by PyTorch, and 5.59 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['A21TR http://staircon.com/ <br>Export by <b>Excel ']...: CUDA out of memory. Tried to allocate 3.84 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.76 GiB is allocated by PyTorch, and 6.51 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Evaluating Validation Pairs:   1%|          | 10/1000 [00:00<01:20, 12.25it/s]ERROR:__main__:Error processing batch with captions ['Old Mug Free to use Old Mug 3D model made in Maya.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Pirate flag animate loop Pirate flag animate loop,']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Closet A simplistic wall closet for your house mod']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   1%|▏         | 13/1000 [00:01<01:05, 14.97it/s]ERROR:__main__:Error processing batch with captions ['Belval SquareMile - Version 0 (2016) - Low Resolut']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Mining cart medieval A worn wooden wheelbarrow use']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Govan Graveyard 237 Produced as part of the Govan ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   2%|▏         | 16/1000 [00:01<01:01, 16.07it/s]ERROR:__main__:Error processing batch with captions ['ESP VD CAP Chem Treatment and desander to ESP']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Thu, 09 Aug 2018 20:23:16 Newfields Design Gallery']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['New York Apartment Home Design 3D']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   2%|▏         | 19/1000 [00:01<00:51, 18.96it/s]ERROR:__main__:Error processing batch with captions ['Morgan Urban custom body']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['TL5477AX Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   2%|▏         | 21/1000 [00:01<00:54, 18.05it/s]ERROR:__main__:Error processing batch with captions ['DAE - Caproni Ca.5 Flying Circus assignment for ga']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Beveled Rim Bowl from Jebel Aruda Pottery found du']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Cabinet Remember my childhood, I don't know why."]...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   2%|▏         | 24/1000 [00:01<00:55, 17.55it/s]ERROR:__main__:Error processing batch with captions ['Puzzle Box 09 A 10x10x10cm Replica of a LeMarchand']...: CUDA out of memory. Tried to allocate 6.37 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 8.29 GiB is allocated by PyTorch, and 3.98 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Lighthouse island Lighthouse Island diorama']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Mihashira Torii(Kyoto Japan) Mihashira Torii are a']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   3%|▎         | 27/1000 [00:01<00:50, 19.40it/s]ERROR:__main__:Error processing batch with captions ['ROI022-380-01 Groundstone Celt collected in Allen ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["L'Ours et l'Amateur des jardins By Victor Peter, 1"]...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   3%|▎         | 29/1000 [00:01<00:51, 19.01it/s]ERROR:__main__:Error processing batch with captions ['Davaab Bomber Custom star wars design based of the']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Test Sword 2 This is a test Sword I have made on m']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Sat, 29 Jun 2019 19:01:48 Newfields Design Gallery']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   3%|▎         | 32/1000 [00:02<00:44, 21.58it/s]ERROR:__main__:Error processing batch with captions ['Anvil An anvil, I modelled and textured in a day.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['UTSC F2 This is a teaching object of the Universit']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Egg simple egg pickup or prop.. food item.. whatev']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   4%|▎         | 35/1000 [00:02<00:44, 21.80it/s]ERROR:__main__:Error processing batch with captions ['Designer Storage Box 7 Designer storage box with s']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Nissan-GT-R Liberty Walk Silver and Blue the weird']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Radio Simple radio in a style which should get the']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   4%|▍         | 38/1000 [00:02<00:50, 18.99it/s]ERROR:__main__:Error processing batch with captions ['Liquid Splash 2 Free high-poly liquid splash mesh.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Magnum S&W M19 It is Smith & Wesson's M19.\nI imagi"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Erect Cat It's ...a real cat"]...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   4%|▍         | 41/1000 [00:02<00:46, 20.43it/s]ERROR:__main__:Error processing batch with captions ['u http://staircon.com/ <br>Export by <b>ProStair</']...: CUDA out of memory. Tried to allocate 4.73 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.66 GiB is allocated by PyTorch, and 5.62 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Sword: Golden Eagle An Exotic sword that is belong']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Biforcate Projectile Point A chert biforcate proje']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   4%|▍         | 44/1000 [00:02<00:43, 21.73it/s]ERROR:__main__:Error processing batch with captions ['HJ19307 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['MastCam-Z Images Processed With Apple New OC Here ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['EB Created with 3DR Solo, GoPro Hero 4 and Autodes']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   5%|▍         | 47/1000 [00:02<00:50, 19.01it/s]ERROR:__main__:Error processing batch with captions ['Mur 2 Castelas Larzac My 3D asset generated with p']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['183656 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['21B22 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   5%|▌         | 50/1000 [00:02<00:52, 18.19it/s]ERROR:__main__:Error processing batch with captions ['Sten MK2 Submachine gun The Sten MK2 is one of man']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Toyota Hilux https://www.google.com/url?sa=i&url=h']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Pagan Statue Pagan Statue / Candle Statue Decorati']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   5%|▌         | 53/1000 [00:03<00:46, 20.23it/s]ERROR:__main__:Error processing batch with captions ['Inktober #3 - Bait Entry for the [Sketchfab 3D Ink']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['spiked cube Test']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['HoneymoonBeach130718Section2Model Images taken in ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   6%|▌         | 56/1000 [00:03<00:47, 19.77it/s]ERROR:__main__:Error processing batch with captions ['上流側22〜27 Uploaded with 3dScannerApp.com']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Inner cell structure I've done an eBook that tries"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['OmniWrenchV.2 Verson 2 with UV maps for DGM 1660. ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Colonist Armor Thingy A low poly brassy coppery st']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   6%|▌         | 60/1000 [00:03<00:39, 23.94it/s]ERROR:__main__:Error processing batch with captions ['Chuo Store Japanese House modeled in blender - No ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Madame Blueberry's Outfit (Casual) Outfit worn by "]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['ヒマラヤゴヨウ2\u3000Pinus griffithii Specimen sampled at Kami']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   6%|▋         | 63/1000 [00:03<00:45, 20.69it/s]ERROR:__main__:Error processing batch with captions ['Diamond Part of Collictible Item Pack for Unreal E']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Coronal Slice 9 9th coronal slice out of 12 derive']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['MODEL Created by Scann3D candidate/3.1.0-10024\n\n* ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   7%|▋         | 66/1000 [00:03<00:47, 19.70it/s]ERROR:__main__:Error processing batch with captions ['21022AB Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Felipe Gonzalez P2 Created with Polycam']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Wanhao Duplicator 5S 3D-print Build Volume Max 3D-']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   7%|▋         | 69/1000 [00:03<00:49, 18.83it/s]ERROR:__main__:Error processing batch with captions ['Farmacias Similares A free model that I made when ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Marine SculptJanuary18 Day 12: Marine. A punky fis']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Simple stool Simple stool withs uvs\nMade with 3ds ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   7%|▋         | 72/1000 [00:04<00:48, 19.04it/s]ERROR:__main__:Error processing batch with captions ['TF2 - Grenade launcher - 128 - One crossed wire, o']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Cup **hI PLEASE  FOLLOW ME AS I AM YOUR FRIEND And']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Croatia Krka Chapel Small chapel in Krka national ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   8%|▊         | 75/1000 [00:04<00:45, 20.21it/s]ERROR:__main__:Error processing batch with captions ['3D printed Scan Dimension logo - SOL We 3D printed']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Bob-Bomb Published by 3ds Max']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Hollywood spanish mansion Home Design 3D']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   8%|▊         | 78/1000 [00:04<00:42, 21.47it/s]ERROR:__main__:Error processing batch with captions ['Madness Combat Grunt So, this is my first characte']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Wood-lawn Cemetery Created with Polycam']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Realistic robot this is the Realistic texture for ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Environment Blockout - My Fridge blockout of my fr']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   8%|▊         | 82/1000 [00:04<00:37, 24.54it/s]ERROR:__main__:Error processing batch with captions ['Park bench this is a model of a park bench']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Smol Sana & Bread Car It is a Sana model of Walfie']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Flourescent Lighting Testing, and wound up with an']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   8%|▊         | 85/1000 [00:04<00:35, 25.61it/s]ERROR:__main__:Error processing batch with captions ['Minecraft 夢幻龍族傳說 藍色小樹樁 Designed by Syterben_bloss ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['American wooden house Free low-poly 3D model 3rd w']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Matatu Collection and item number: David and Becky']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:   9%|▉         | 88/1000 [00:04<00:39, 23.13it/s]ERROR:__main__:Error processing batch with captions ['Eratosthenes Made in Gravity Sketch']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Shell Flat flat shell']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Oil Filter This model comes in GLB format as stand']...: CUDA out of memory. Tried to allocate 3.81 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.73 GiB is allocated by PyTorch, and 6.54 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Evaluating Validation Pairs:   9%|▉         | 91/1000 [00:04<00:41, 21.87it/s]ERROR:__main__:Error processing batch with captions ['SURPRISED PATRICK surpriesed patrick ready to prin']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['иконостас у цркви св. Богородице, Димитровград The']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Garden Fences (Wood) Garden Fence, on low ploy \nIf']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['India - Jammu and Cachemire * Generator: [DEM Net ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  10%|▉         | 95/1000 [00:04<00:38, 23.76it/s]ERROR:__main__:Error processing batch with captions ['Spider animated character Animations\n\n* idle\n* idl']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Battery Mendel Bunker Scan 📍 [Marin Headlands, Sau']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Bond Street Scan by Chelmsford Creatives']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  10%|▉         | 98/1000 [00:05<00:36, 24.49it/s]ERROR:__main__:Error processing batch with captions ['Jango & Boba jango fett was the father of Boba and']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['The automated school ...']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Cubik Model Designed by Gamerkm with Cubik Studio ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['(Low Poly) Optimist Boat Low Poly Optimist Boat ma']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  10%|█         | 102/1000 [00:05<00:34, 26.23it/s]ERROR:__main__:Error processing batch with captions ['R34 Skyline for education']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['California penthouse Home Design 3D']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Stylized Halloween Cauldron Stylized Halloween Cau']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  10%|█         | 105/1000 [00:05<00:36, 24.38it/s]ERROR:__main__:Error processing batch with captions ['Petroglyph J6 Khatm Al Melaha, Kalba, Sharjah Natu']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Enlight Flatwear Box flatware storage box']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['p-391-2019_krata_budziszewice Building exported fr']...: CUDA out of memory. Tried to allocate 4.54 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.46 GiB is allocated by PyTorch, and 5.81 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Evaluating Validation Pairs:  11%|█         | 108/1000 [00:05<00:41, 21.54it/s]ERROR:__main__:Error processing batch with captions ['Ring of honor Custom Ring Design\nRhino + zbrush\nte']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['L http://staircon.com/ <br>Export by <b>ProStair</']...: CUDA out of memory. Tried to allocate 4.70 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.62 GiB is allocated by PyTorch, and 5.65 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Holiday House Home Design 3D']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  11%|█         | 111/1000 [00:05<00:40, 21.81it/s]ERROR:__main__:Error processing batch with captions ['Baby Student project. Photogrammetry from toy doll']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Rush7 rush glitch']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Rhino Tooth This is a downsampled version of the "']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Mechanics Tool Chest with Top Box Mechanics Tool C']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  12%|█▏        | 115/1000 [00:05<00:40, 22.11it/s]ERROR:__main__:Error processing batch with captions ['1 Get the Trnio app at www.trnio.com']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Hand-Painted Weapons Hand-Painted, unlit stone wea']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Low Poly Tree Stump This simple 3D tree stump is t']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['F100 The North American F-100 Super Sabre was an A']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  12%|█▏        | 119/1000 [00:05<00:35, 25.10it/s]ERROR:__main__:Error processing batch with captions ['Generic Character A generic character made in Maya']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['200267 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Clemenia - Lab 2 A basic house I made while learni']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  12%|█▏        | 122/1000 [00:06<00:39, 22.21it/s]ERROR:__main__:Error processing batch with captions ["Printer - Household Props Challenge - Day 8 Here's"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['2008011J__réf._LAHEUX_-_BASTARD Building exported ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['オニユリ Tiger Lily, Lilium lancifolium Ikinoshima Isl']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  12%|█▎        | 125/1000 [00:06<00:42, 20.52it/s]ERROR:__main__:Error processing batch with captions ['Dining Table Created in Autodesk Fusion 360.\n# Woo']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['200159 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['L http://staircon.com/ <br>Export by <b>ProStair</']...: CUDA out of memory. Tried to allocate 4.20 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.12 GiB is allocated by PyTorch, and 6.15 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Evaluating Validation Pairs:  13%|█▎        | 128/1000 [00:06<00:45, 19.30it/s]ERROR:__main__:Error processing batch with captions ['Rock Rock created in Blender..']...: CUDA out of memory. Tried to allocate 4.15 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.08 GiB is allocated by PyTorch, and 6.20 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['C5068 Ayios Christos: Cave * [Helladic.info Link](']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Britonnic Storehouse A storehouse I made as a repl']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  13%|█▎        | 131/1000 [00:06<00:49, 17.51it/s]ERROR:__main__:Error processing batch with captions ['Guanyu Animation chinese hero']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['My first sword This is my first sword']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Vacume manafold adapter This is a adapter for a va']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  13%|█▎        | 134/1000 [00:06<00:43, 19.89it/s]ERROR:__main__:Error processing batch with captions ['Timber trusses for primary school Timber trusses f']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Point Cube A 3D cube of points that displays diffe']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['MALE BOXERS 20 Male Boxers.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Bivalve: Ostrea antarctica (PRI 59446) Fossil shel']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  14%|█▍        | 138/1000 [00:07<00:40, 21.24it/s]ERROR:__main__:Error processing batch with captions ['624230040 Jackie Rumba Dancing Discription -> Mode']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Among us char The eyes are really black when u dow']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['TRS-80 Color Computer 2 Including downloadable so ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Celestial Treasure “***Somewhere, something incred']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  14%|█▍        | 142/1000 [00:07<00:37, 22.68it/s]ERROR:__main__:Error processing batch with captions ['Coca Cola Can A simple coca-cola can test.\n\n*If yo']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['LowPoly car # ![You are free to download it and us']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['helmet Hi, I recently started modeling and I want ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  14%|█▍        | 145/1000 [00:07<00:37, 23.00it/s]ERROR:__main__:Error processing batch with captions ['Naoko - Studio Ghibli Naoko Satomi from the movie ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['190923_taavinharju 28 http://staircon.com/ <br>Exp']...: CUDA out of memory. Tried to allocate 4.35 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.27 GiB is allocated by PyTorch, and 6.00 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['ヤマアカガエル ♂ Montane Brown Frog, Rana ornativentris K']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  15%|█▍        | 148/1000 [00:07<00:35, 24.06it/s]ERROR:__main__:Error processing batch with captions ['Workbench Game Ready Workbench for free \n\nYou can ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Robot A robot I created in Maya years ago for a cl']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Medieval Labyrinth - Stairs Mid Part of my entry f']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Steven in 3D! Steven universe model mad by me\n\nSte']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  15%|█▌        | 152/1000 [00:07<00:31, 26.87it/s]ERROR:__main__:Error processing batch with captions ['Wed, 03 Oct 2018 16:16:48 Newfields Design Gallery']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['For the Pet Owner Home Design 3D']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Bullpuppy some bullpup design\n\nparts are seperated']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['YPM ANT.232012 Pottery Bowl from the Yale Peabody ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  16%|█▌        | 156/1000 [00:07<00:35, 23.73it/s]ERROR:__main__:Error processing batch with captions ['Orb Calibur The Orb Calibur (オーブカリバー Ōbu Karibā) i']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Dariusz_Gołębiowski Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Rand Tower Rand Tower was constructed from 1928 to']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  16%|█▌        | 159/1000 [00:07<00:36, 23.25it/s]ERROR:__main__:Error processing batch with captions ['Osthellinga http://staircon.com/ <br>Export by <b>']...: CUDA out of memory. Tried to allocate 4.03 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.95 GiB is allocated by PyTorch, and 6.32 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Villa Rosario. Barcelona Villa Rosario is a small ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Drobak http://staircon.com/ <br>Export by <b>Stolm']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  16%|█▌        | 162/1000 [00:08<00:41, 20.25it/s]ERROR:__main__:Error processing batch with captions ['Attack on Titan - Badges My First Work on Sketchfa']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['20th Century Fox Film Corporation Logo (2009-201 M']...: CUDA out of memory. Tried to allocate 3.63 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.56 GiB is allocated by PyTorch, and 6.72 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Wooden Horse Trough 3D Model This is a wooden hors']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  16%|█▋        | 165/1000 [00:08<00:39, 21.16it/s]ERROR:__main__:Error processing batch with captions ['Arcade Maze 3Dcember 2020 My first entry for the 3']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Circus Baby and Bidybab Yay. \n\nThey are nice looki']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Snail race First try with Photogrammetry using 3DF']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  17%|█▋        | 168/1000 [00:08<00:37, 22.06it/s]ERROR:__main__:Error processing batch with captions ['LED Chessboard This is a board designed for LED Ch']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['AS9427SO Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['38:115.300_1-2径間1/3桁下 Uploaded with 3dScannerApp.c']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  17%|█▋        | 171/1000 [00:08<00:38, 21.31it/s]ERROR:__main__:Error processing batch with captions ['The palm park Home Design 3D']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Toon Sword A toony type sword']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Small 2 door cabinet Small cabinet with 2 doors']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  17%|█▋        | 174/1000 [00:08<00:37, 22.28it/s]ERROR:__main__:Error processing batch with captions ['TukTuk Wood I decorative wooden TukTuk. I made thi']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['u http://staircon.com/ <br>Export by <b>ProStair</']...: CUDA out of memory. Tried to allocate 4.95 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.88 GiB is allocated by PyTorch, and 5.40 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['House-ver4-small My asset for A-Frame community']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  18%|█▊        | 177/1000 [00:08<00:38, 21.48it/s]ERROR:__main__:Error processing batch with captions ['Sea Star F: Ophiotrichidae\n\nAccession number: 759.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Stone Pack001 click like if you want to download o']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Peugeot 5008 (2010) good car out 2010']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  18%|█▊        | 180/1000 [00:08<00:36, 22.52it/s]ERROR:__main__:Error processing batch with captions ['Sovereign potters plate Family heirloom']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['MacDonalds Rest-Com-v5 Maccas @ Coomera']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['"Bouche à lèvres" A little scene tightly inspired ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Street Art Doorway (iPhone Lidar Scan) Scan taken ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  18%|█▊        | 184/1000 [00:09<00:34, 23.57it/s]ERROR:__main__:Error processing batch with captions ["Little's island lighthouse This model has been cre"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['character of wars games this character names adam ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Shell hash Snail and disarticulated clam shells in']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  19%|█▊        | 187/1000 [00:09<00:35, 23.14it/s]ERROR:__main__:Error processing batch with captions ['Low Poly Handtools Table Low Poly Handtools Table']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Well A well with a special inside if the textures ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Roman Glass Jar Roman glass jar made in Maya 3D fo']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  19%|█▉        | 190/1000 [00:09<00:35, 22.58it/s]ERROR:__main__:Error processing batch with captions ['Acanthe Acanthe\n\n174 pics\nmade with agisoft']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Red and Blue DIY Edition This is Famour Red and Bl']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Walther P99 I finished it for a long time, I didn'"]...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  19%|█▉        | 193/1000 [00:09<00:35, 22.95it/s]ERROR:__main__:Error processing batch with captions ['Project 1 Sculpture my model for assignment 1']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Sat, 01 Jun 2019 17:10:14 Newfields Design Gallery']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['A21003 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  20%|█▉        | 196/1000 [00:09<00:36, 22.13it/s]ERROR:__main__:Error processing batch with captions ['Assets Desert Hope someone find good use for this.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Fast Food Poster Fast food poster low poly model']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['22431C Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  20%|█▉        | 199/1000 [00:09<00:39, 20.40it/s]ERROR:__main__:Error processing batch with captions ['Confine di stato Kres burnt border 01']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Sword Low poly sword model']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['New Model Uploaded with 3dScannerApp.com']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  20%|██        | 202/1000 [00:09<00:37, 21.54it/s]ERROR:__main__:Error processing batch with captions ['AOI_192_MW_20200122 this is my test thing']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Groot My first character']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Camp Table A standard but sturdy camp table. Prett']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Untitled Scan Uploaded with 3dScannerApp.com']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  21%|██        | 206/1000 [00:09<00:30, 25.73it/s]ERROR:__main__:Error processing batch with captions ['COINS COINS scanning by Thunk3D jewelry 3d scanner']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['019_2020 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['House Concept: https://www.artstation.com/artwork/']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  21%|██        | 209/1000 [00:10<00:35, 22.41it/s]ERROR:__main__:Error processing batch with captions ["3 more Detailed Drafts Ecco's Time Device\nOld Beet"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Primordial Room First Iteration low poly level set']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['2 lorries wc We']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  21%|██        | 212/1000 [00:10<00:36, 21.58it/s]ERROR:__main__:Error processing batch with captions ['Olivia Scan by ModBod3d (http://codame.com/project']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Frommer STOP Basic model of a Frommer STOPY type p']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['5G Made by Ines Soares,']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Rockstar Freddy Model Fully rigged and everything.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  22%|██▏       | 216/1000 [00:10<00:30, 25.74it/s]ERROR:__main__:Error processing batch with captions ['Planet Of Phoenix Planet Phoenix from the game Era']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Nevra412-S http://staircon.com/ <br>Export by <b>M']...: CUDA out of memory. Tried to allocate 3.64 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.56 GiB is allocated by PyTorch, and 6.71 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Viper Steam Carbine I have created a normal lookin']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Bathtub jet system Very nice bathtub jet system mo']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  22%|██▏       | 220/1000 [00:10<00:27, 28.34it/s]ERROR:__main__:Error processing batch with captions ['Bronze Age Soft-Stone Bowl, Jebel al-Buhais Bronze']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Australian Magpie (Gymnorhina tibicen) Skull of Au']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Half Inch PVC Pipe Mount A half inch pipe mount wi']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['medieval asset 18\\ cart A wooden cart']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  22%|██▏       | 224/1000 [00:10<00:26, 29.37it/s]ERROR:__main__:Error processing batch with captions ['Spaceship A spaceship I modelled and textured.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Wooden bridge (WE in Point Reyes) Scanned with Sce']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Ferritin Molecular Structure Crystal structure of ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Storheim - hytte v.4 without roof Storheim - hytte']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  23%|██▎       | 228/1000 [00:10<00:25, 30.32it/s]ERROR:__main__:Error processing batch with captions ['0027_ElkCreek_Mesh_ab5e65cf this is my test thing']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Garden ornament Hideous solid concrete thing in th']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Chyby_-_Najdek Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['J20037A Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  23%|██▎       | 232/1000 [00:10<00:30, 24.99it/s]ERROR:__main__:Error processing batch with captions ['1956 Fiat 500 Low Poly Another low poly car I made']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Scorpio 76 Cinema 4D, Zbrush, 3D-Coat,Sci-Fi, Scif']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['5 Versions Of Camera 5 versions of camera Canon-AE']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  24%|██▎       | 235/1000 [00:11<00:29, 26.03it/s]ERROR:__main__:Error processing batch with captions ["Lizard Cowboy Here's a little low-poly cowboy liza"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Monument Valley VR Ida can not be friends with a t']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['4_29 hardscape class work']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Human Calcaneus Real human calcaneus. Scanned by s']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Street Light Citty street lite']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  24%|██▍       | 240/1000 [00:11<00:24, 30.58it/s]ERROR:__main__:Error processing batch with captions ['RTJ NEON 2 Based on "[RTJ Hands](https://sketchfab']...: 'str' object has no attribute 'type'
# ...
# ERROR:__main__:Error processing batch with captions ['Roman Tombstone Located in British Museum\n\n2nd - 4']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Yeehaw Wand Draw #10312008725 Hand draw via Yeehaw']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  92%|█████████▏| 922/1000 [00:43<00:03, 20.81it/s]ERROR:__main__:Error processing batch with captions ['210515 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Tue, 13 Aug 2019 17:00:03 Newfields Design Gallery']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Pitted Hammerstone (2101a344) **Pitted Hammerstone']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  92%|█████████▎| 925/1000 [00:43<00:03, 20.16it/s]ERROR:__main__:Error processing batch with captions ['Etruscan Wine Bucket This [Etruscan](https://en.wi']...: CUDA out of memory. Tried to allocate 3.95 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.87 GiB is allocated by PyTorch, and 6.40 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Cain Cain after the murder of Abel in the Tuilleri']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Lacock North Doorway Apotropaic Motifs Wiltshire M']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['4x4 Low Poly Truck Present to you a low poly truck']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  93%|█████████▎| 929/1000 [00:43<00:03, 21.74it/s]ERROR:__main__:Error processing batch with captions ['Hip Hop Dancing test']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Chevrolet WB 30 CWT Truck WW2 Desert truck, now lo']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Small horseshoe crab Small dead horseshoe crab fou']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  93%|█████████▎| 932/1000 [00:43<00:02, 23.54it/s]ERROR:__main__:Error processing batch with captions ['Blob Tesselation Shader']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['V8 Tomato Juice Scan of V8 Tomato Juice']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Wires Right Side ![WiresR](https://i.ibb.co/k5h2Cc']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Windows Vista Downloads Folder ***yeah.. it's this"]...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  94%|█████████▎| 936/1000 [00:44<00:02, 25.57it/s]ERROR:__main__:Error processing batch with captions ['Table Simple Table model, completely free, not rea']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['dragonquest Princess Laura/Gwealin mesh mod dragon']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['MK 235 cassette recorder The MK 235 cassette recor']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  94%|█████████▍| 939/1000 [00:44<00:02, 24.16it/s]ERROR:__main__:Error processing batch with captions ['Ollie_May2021 http://staircon.com/ <br>Export by <']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Shoe Test Blyat']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Botanical Adventure Kit [![](https://blog.sketchfa']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  94%|█████████▍| 942/1000 [00:44<00:02, 22.16it/s]ERROR:__main__:Error processing batch with captions ['Gypsum panel of an archer, palace of Sargon II Gyp']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Lowpoly origami whale Lowpoly 3D model of whale st']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Lemon Head This is a Lemon with a Face on it.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  94%|█████████▍| 945/1000 [00:44<00:02, 23.45it/s]ERROR:__main__:Error processing batch with captions ['Bath 📍 [Warwick, England](https://scaniver.se/L52.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['TARP 2019: Bath Latrine Entrance Photogrammetric c']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Winchester 1887 shotgun Trying to recreate the Win']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  95%|█████████▍| 948/1000 [00:44<00:02, 24.38it/s]ERROR:__main__:Error processing batch with captions ['Glassy clast from suevite,  Germany Glassy clast (']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['toy bonnie but its weird why take a geuss why?']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Moon Black Honed Moon Black Honed Chinese granite ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  95%|█████████▌| 951/1000 [00:44<00:01, 25.00it/s]ERROR:__main__:Error processing batch with captions ['Spartan Shild Low-poly spartan shild for using in ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Rocket It's realistic toy rocket. Make with Blende"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Brougham v1 3D wagon model without texture.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  95%|█████████▌| 954/1000 [00:44<00:01, 25.04it/s]ERROR:__main__:Error processing batch with captions ['Goat-corpse-photogrammetry scan Photogrammetry sca']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["discord man > This is my 2nd job\n> don't judge str"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ["Lucario Aura Pokémon\nLucario reads its opponent's "]...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  96%|█████████▌| 957/1000 [00:44<00:01, 24.76it/s]ERROR:__main__:Error processing batch with captions ['Wasserbüffel und Knabe Water buffalo with boy by E']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Monocopter V2 2nd Prototype']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Upper Surface of computer mouse This is upside (Up']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  96%|█████████▌| 960/1000 [00:45<00:01, 25.39it/s]ERROR:__main__:Error processing batch with captions ['Vivid Reality Logo 3D Model Vivid Reality Original']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['The Barrel Hello! The Barrel designed with Blender']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['0-0418AB Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  96%|█████████▋| 963/1000 [00:45<00:01, 21.54it/s]ERROR:__main__:Error processing batch with captions ['Chimera "Duckolidra" #3DSM3 I\'m not serious at all']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Brickwork Pillar Just a quick experiment.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['New Model Uploaded with 3dScannerApp.com']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  97%|█████████▋| 966/1000 [00:45<00:01, 20.70it/s]ERROR:__main__:Error processing batch with captions ['Both SMG/E-11Grips Just to show them side by side']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['natto4 Get the Trnio app at www.trnio.com']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Traditional marble floor Marble floor 3D scanning ']...: CUDA out of memory. Tried to allocate 3.70 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.62 GiB is allocated by PyTorch, and 6.65 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Evaluating Validation Pairs:  97%|█████████▋| 969/1000 [00:45<00:01, 22.01it/s]ERROR:__main__:Error processing batch with captions ['Old Well This is old well 3d model.']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Untitled Scan Uploaded with 3dScannerApp.com']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Chess Horse a simple chess horse.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  97%|█████████▋| 972/1000 [00:45<00:01, 20.05it/s]ERROR:__main__:Error processing batch with captions ['S28-24-5-2022 http://staircon.com/ <br>Export by <']...: CUDA out of memory. Tried to allocate 4.16 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 6.08 GiB is allocated by PyTorch, and 6.19 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ['Black Widow Mech Tiny but deadly? Lumbering menace']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['FNAF - Security Breach - Monty Gator - Hour 3 This']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  98%|█████████▊| 975/1000 [00:45<00:01, 22.05it/s]ERROR:__main__:Error processing batch with captions ['My version of a friends 4Runner Why? Because why n']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Foreshaft for Toggling Harpoon, XCB-105-4129 Bone ']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Polycam capture Created with Polycam']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Dustbin A Dustbin made using Blender 2.79 and the ']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  98%|█████████▊| 979/1000 [00:46<00:00, 21.93it/s]ERROR:__main__:Error processing batch with captions ['The Pokeball The Pokeball from the well-known seri']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Videogame Controller from Poly by Google This is a']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['schody http://staircon.com/ <br>Export by <b>ProSt']...: CUDA out of memory. Tried to allocate 3.62 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.54 GiB is allocated by PyTorch, and 6.73 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# Evaluating Validation Pairs:  98%|█████████▊| 982/1000 [00:46<00:00, 21.34it/s]ERROR:__main__:Error processing batch with captions ['Circus Home Design 3D']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['converse shoes']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Dartmouth Assets - Harbourwalk Sign Commonly spott']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Man-At-Arms Hand Gun - Free 3D Concept Art of an o']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  99%|█████████▊| 986/1000 [00:46<00:00, 24.25it/s]ERROR:__main__:Error processing batch with captions ['087641 Building exported from Pamir.']...: CUDA out of memory. Tried to allocate 3.85 GiB. GPU 0 has a total capacity of 14.74 GiB of which 2.34 GiB is free. Process 21339 has 12.40 GiB memory in use. Of the allocated memory 5.77 GiB is allocated by PyTorch, and 6.50 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# ERROR:__main__:Error processing batch with captions ["Artoria Pendragon Sword It's another model I think"]...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Petit Trianon Transparent Black 3 Published by 3ds']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  99%|█████████▉| 989/1000 [00:46<00:00, 23.99it/s]ERROR:__main__:Error processing batch with captions ['HIM PowerPuff Girls My contribution to the Cartoon']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Mindless | 3D Inktober 2019 Second entry for the 3']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Indoor Plant Dieffenbachia Captured with @Scenario']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs:  99%|█████████▉| 992/1000 [00:46<00:00, 23.30it/s]ERROR:__main__:Error processing batch with captions ['Underground Water Channel - 14k tris Envirnoment i']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Plushtrap Fredbears From my fredbear and friends g']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Golina_-_Zieliński Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs: 100%|█████████▉| 995/1000 [00:46<00:00, 23.05it/s]ERROR:__main__:Error processing batch with captions ['Planty Household plant, water it, love it, it will']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Demo Only for demo']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['Low-Poly Stolzer & Son Double Deuce A massive, hea']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs: 100%|█████████▉| 998/1000 [00:46<00:00, 24.54it/s]ERROR:__main__:Error processing batch with captions ['ROI040-010-06 Commisary Point collected in Fayette']...: 'str' object has no attribute 'type'
# ERROR:__main__:Error processing batch with captions ['21.072 Building exported from Pamir.']...: 'str' object has no attribute 'type'
# Evaluating Validation Pairs: 100%|██████████| 1000/1000 [00:46<00:00, 21.31it/s]
# Chamfer Distance Results:
# Maximum: 4.001132
# Minimum: 0.008774
# Average: 0.288238
